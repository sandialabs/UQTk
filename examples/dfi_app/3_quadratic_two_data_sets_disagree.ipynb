# %% [markdown]
# # Example: quadratic line fitting (3)

# %% [markdown]
# A third example of how to use the calibration code with two disagreeing data sets.

# %%
# import statements
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle as pk
import subprocess
import shlex
import tempfile

# %%
# special imports
from utils import *

# %%
# pyplot settings
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## 1. Setup

# %%
# the model to fit
def f(x, a=-2, b=0, c=2):
    return a*(x - b)**2 + c

# %%
# lower and upper bounds for the parameters
a_low = -3; a_upp = -1
b_low = -0.1; b_upp = 0.1
c_low = 1; c_upp = 3

# %%
# data sets
ndata = 2

xdata = []
ydata = []
sdata = []

# first data set
xdata.append(np.arange(start=0, stop=2.5, step=0.5))
ydata.append(np.array([f(x, a=-1) for x in xdata[-1]]))
sdata.append(np.array([1/2 - f(x)/6 for x in xdata[-1]]))

# second data set
xdata.append(np.arange(start=0.25, stop=2.25, step=0.5))
ydata.append(np.array([f(x, a=-3) for x in xdata[-1]]))
sdata.append(np.array([1/2 - f(x)/6 for x in xdata[-1]]))

# %%
# plot model evaluations and data
x = np.linspace(0, 2)
n = 100
_, ax = plt.subplots(figsize=(8, 5))
for _ in range(n):
    a = (a_upp - a_low)*np.random.rand() + a_low
    b = (b_upp - b_low)*np.random.rand() + b_low
    c = (c_upp - c_low)*np.random.rand() + c_low
    ax.plot(x, f(x, a=a, b=b, c=c))
for j, color in enumerate(["blue", "red"]):
    ax.errorbar(xdata[j], ydata[j], yerr=sdata[j], color=color, linewidth=0, elinewidth=2, capsize=6, marker="o", capthick=2, zorder=100, label=f"data {j + 1}")
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
ax.set_title("quadratic model")
ax.legend(loc="lower left", frameon=False)
if save:
    plt.savefig(os.path.join(save_location, "example_3_quadratic.png"))
plt.show()

# %% [markdown]
# ## 2. Surrogate construction

# %%
# construct surrogate models for each data set
results = []
for j in range(ndata):

    # generate data
    n = 100
    xs = []
    ys = []
    for _ in range(n):
        a = (a_upp - a_low)*np.random.rand() + a_low
        b = (b_upp - b_low)*np.random.rand() + b_low
        c = (c_upp - c_low)*np.random.rand() + c_low
        xs.append([a, b, c])
        ys.append(f(xdata[j], a=a, b=b, c=c))
    xs = np.vstack(xs)
    ys = np.vstack(ys)

    # construct surrogate models
    with tempfile.TemporaryDirectory() as tmp:

        # save input and output data
        np.savetxt(os.path.join(tmp, "ptrain.dat"), xs)
        np.savetxt(os.path.join(tmp, "qtrain.dat"), xs)
        np.savetxt(os.path.join(tmp, "ytrain.dat"), ys)

        # save parameter ranges
        np.savetxt(os.path.join(tmp, "param_ranges.dat"), np.array([[a_low, a_upp], [b_low, b_upp], [c_low, c_upp]]))

        # run wibcs
        subprocess.run(shlex.split(f"{path_to_python} {path_to_uq_pc} -r offline_post -p param_ranges.dat -m lsq -n {xs.shape[0]} -s rand -t 2 -z"), cwd=tmp, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        # load results
        with open(os.path.join(tmp, "results.pk"), "rb") as file:
            results.append(pk.load(file))

# %%
# plot PCE accuracy
for d in range(ndata):
    _, ax = plt.subplots(figsize=(8, 5))
    for i in range(len(results[d]["pcmi"][0])):
        ytrain = results[d]["training"][2][:, i]
        ytrain_pce = results[d]["training"][3][:, i]
        ax.scatter(ytrain, ytrain_pce)
    ax.set_xlabel("model output")
    ax.set_ylabel("PCe prediction")
    ax.set_title(f"PCE parity plot (data set {d + 1})")
    if save:
        plt.savefig(os.path.join(save_location, f"example_2_parity_{d + 1}.png"))
    plt.show()

# %% [markdown]
# ## 3. Calibration

# %%
# perform calibration
with tempfile.TemporaryDirectory() as tmp:

    # save data mean and error bars
    for d in range(ndata):
        np.savetxt(os.path.join(tmp, f"data.{d + 1}.dat"), np.vstack([ydata[d], sdata[d]]).T)

    # save PCE coefficients and multi-indices
    for d in range(ndata):
        for n in range(len(results[d]["pcmi"][0])):
            np.savetxt(os.path.join(tmp, f"pccf.{d + 1}.{n + 1}.dat"), results[d]["pcmi"][0][n])
            np.savetxt(os.path.join(tmp, f"mindex.{d + 1}.{n + 1}.dat"), results[d]["pcmi"][1][n], fmt="%d")
            np.savetxt(os.path.join(tmp, f"pushforward.pccf.{2*n + d + 1}.dat"), results[d]["pcmi"][0][n])
            np.savetxt(os.path.join(tmp, f"pushforward.mindex.{2*n + d + 1}.dat"), results[d]["pcmi"][1][n], fmt="%d")

    # save prior
    with open(os.path.join(tmp, "prior.dat"), "w") as file:
        file.write(f"gaussian {(a_low + a_upp)/2} {(a_upp - a_low)/2}\n")
        file.write(f"gaussian {(b_low + b_upp)/2} {(b_upp - b_low)/2}\n")
        file.write(f"gaussian {(c_low + c_upp)/2} {(c_upp - c_low)/2}\n")

    # run calibration
    subprocess.run(shlex.split(path_to_dfi + " -v pushforward.pccf.{n}.dat -w pushforward.mindex.{n}.dat -g 0.1 -k 100 -m 0"), cwd=tmp)

    # load output files
    chain = np.loadtxt(os.path.join(tmp, "chain.dat"))
    pushforward = []
    n = 1
    pushforward_file = os.path.join(tmp, f"pushforward.1.{n}.dat")
    while os.path.isfile(pushforward_file):
        pushforward.append(np.loadtxt(pushforward_file))
        n += 1
        pushforward_file = os.path.join(tmp, f"pushforward.1.{n}.dat")
    synthetic_data = []
    for d in range(ndata):
        synthetic_data.append(np.loadtxt(os.path.join(tmp, f"synthetic.data.{d + 1}.dat")))
# Out:
# ╭────────────────────────────────────────────────────╮
# │                       dfi.x                        │
# ╰────────────────────────────────────────────────────╯
# Found prior:
#   => p1   : mu = -2        , sigma = 1
#   => p2   : mu = 0         , sigma = 0.1
#   => p3   : mu = 2         , sigma = 1
# Found 2 data sets:
#   => Data set number 1/2:
#        -> y1   = 2         s1   = 0.166667
#        -> y2   = 1.75      s2   = 0.25
#        -> y3   = 1         s3   = 0.5
#        -> y4   = -0.25     s4   = 0.916667
#        -> y5   = -2        s5   = 1.5
#   => Data set number 2/2:
#        -> y1   = 1.8125    s1   = 0.1875
#        -> y2   = 0.3125    s2   = 0.354167
#        -> y3   = -2.6875   s3   = 0.6875
#        -> y4   = -7.1875   s4   = 1.1875
# Reading 5 PCE models for data set number 1/2...
#   => PCE number 1:
#        -> PCE coefficients read from file pccf.1.1.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.1.dat (10 x 3)
#   => PCE number 2:
#        -> PCE coefficients read from file pccf.1.2.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.2.dat (10 x 3)
#   => PCE number 3:
#        -> PCE coefficients read from file pccf.1.3.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.3.dat (10 x 3)
#   => PCE number 4:
#        -> PCE coefficients read from file pccf.1.4.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.4.dat (10 x 3)
#   => PCE number 5:
#        -> PCE coefficients read from file pccf.1.5.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.5.dat (10 x 3)
# Reading 4 PCE models for data set number 2/2...
#   => PCE number 1:
#        -> PCE coefficients read from file pccf.2.1.dat (10 coefficients)
#        -> Multi-indices read from file mindex.2.1.dat (10 x 3)
#   => PCE number 2:
#        -> PCE coefficients read from file pccf.2.2.dat (10 coefficients)
#        -> Multi-indices read from file mindex.2.2.dat (10 x 3)
#   => PCE number 3:
#        -> PCE coefficients read from file pccf.2.3.dat (10 coefficients)
#        -> Multi-indices read from file mindex.2.3.dat (10 x 3)
#   => PCE number 4:
#        -> PCE coefficients read from file pccf.2.4.dat (10 coefficients)
#        -> Multi-indices read from file mindex.2.4.dat (10 x 3)
# Checking consistency of PCE models and data set 1/2...
#   => PCE number 1    : first PCE coefficient = -0.669913 ; measurement mean = 2
#   => PCE number 2    : first PCE coefficient = -0.669913 ; measurement mean = 1.75
#   => PCE number 3    : first PCE coefficient = -0.669913 ; measurement mean = 1
#   => PCE number 4    : first PCE coefficient = -0.669913 ; measurement mean = -0.25
#   => PCE number 5    : first PCE coefficient = -0.669913 ; measurement mean = -2
# Checking consistency of PCE models and data set 2/2...
#   => PCE number 1    : first PCE coefficient = -0.645174 ; measurement mean = 1.8125
#   => PCE number 2    : first PCE coefficient = -0.645174 ; measurement mean = 0.3125
#   => PCE number 3    : first PCE coefficient = -0.645174 ; measurement mean = -2.6875
#   => PCE number 4    : first PCE coefficient = -0.645174 ; measurement mean = -7.1875
# Constructing PCE surrogate models...
#   => 5 PCE surrogate models created for data set 1/2
#   => 4 PCE surrogate models created for data set 2/2
# Found 2 variance scaling factors:
#   => Data set 1    : variance scaling factor = 1
#   => Data set 2    : variance scaling factor = 1
# Generating synthetic data set for data set number 1/2...
#   => Generated synthetic data set of size 5 x 100
#   => Written synthetic data set to file synthetic.data.1.dat
# Generating synthetic data set for data set number 2/2...
#   => Generated synthetic data set of size 4 x 100
#   => Written synthetic data set to file synthetic.data.2.dat
# Reading pushforward PCE models for data set number 1/2...
#   => PCE number 1:
#        -> PCE coefficients read from file pushforward.pccf.1.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.1.dat (10 x 3)
#   => PCE number 2:
#        -> PCE coefficients read from file pushforward.pccf.2.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.2.dat (10 x 3)
#   => PCE number 3:
#        -> PCE coefficients read from file pushforward.pccf.3.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.3.dat (10 x 3)
#   => PCE number 4:
#        -> PCE coefficients read from file pushforward.pccf.4.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.4.dat (10 x 3)
#   => PCE number 5:
#        -> PCE coefficients read from file pushforward.pccf.5.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.5.dat (10 x 3)
#   => PCE number 6:
#        -> PCE coefficients read from file pushforward.pccf.6.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.6.dat (10 x 3)
#   => PCE number 7:
#        -> PCE coefficients read from file pushforward.pccf.7.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.7.dat (10 x 3)
#   => PCE number 8:
#        -> PCE coefficients read from file pushforward.pccf.8.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.8.dat (10 x 3)
#   => PCE number 9:
#        -> PCE coefficients read from file pushforward.pccf.9.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.9.dat (10 x 3)
# Setting up MCMC chain of length 100000...
#   => Set random seed of the chain to 1657402169
#   => Set chain covariance to 0.01
#   => Set proposal jump size to 0.1
#   => Set adaptivity parameters to:
#        -> Adapt start = 10000
#        -> Adapt step = 10
#        -> Adapt end = 100000
#        -> Eps cov = 1e-08
#   => Set chain print frequency to 10000
#   => Set burnin to 0
#   => Set subsampling rate to 1
#   => Intialized chain to
#        -> p1   : -2
#        -> p2   : 0
#        -> p3   : 2
# Status of chain before running AMCMC:
#   => p1   : -2
#   => p2   : 0
#   => p3   : 2
#   => Data set 1/2:
#        -> x1   : measurement = 2         , prediction = 2.00049
#        -> x2   : measurement = 1.75      , prediction = 1.50049
#        -> x3   : measurement = 1         , prediction = 0.000485449
#        -> x4   : measurement = -0.25     , prediction = -2.49951
#        -> x5   : measurement = -2        , prediction = -5.99951
#   => Data set 2/2:
#        -> x1   : measurement = 1.8125    , prediction = 1.87462
#        -> x2   : measurement = 0.3125    , prediction = 0.874618
#        -> x3   : measurement = -2.6875   , prediction = -1.12538
#        -> x4   : measurement = -7.1875   , prediction = -4.12538
# Starting AMCMC...
# 10 % completed; Chain step 10000
# ================= Current logpost:-24.426150, Max logpost:-22.675645, Accept rate:0.914100
# ================= Current MAP params: par(0)=-1.839637 par(1)=-0.010104 par(2)=2.005021
# Written the states 0 - 10000 to the text file chain.dat
# 20 % completed; Chain step 20000
# ================= Current logpost:-22.984405, Max logpost:-22.671258, Accept rate:0.816850
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 10001 - 20000 to the text file chain.dat
# 30 % completed; Chain step 30000
# ================= Current logpost:-23.299686, Max logpost:-22.671258, Accept rate:0.784433
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 20001 - 30000 to the text file chain.dat
# 40 % completed; Chain step 40000
# ================= Current logpost:-23.865021, Max logpost:-22.671258, Accept rate:0.765525
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 30001 - 40000 to the text file chain.dat
# 50 % completed; Chain step 50000
# ================= Current logpost:-24.069543, Max logpost:-22.671258, Accept rate:0.755600
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 40001 - 50000 to the text file chain.dat
# 60 % completed; Chain step 60000
# ================= Current logpost:-23.655772, Max logpost:-22.671258, Accept rate:0.749517
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 50001 - 60000 to the text file chain.dat
# 70 % completed; Chain step 70000
# ================= Current logpost:-22.883521, Max logpost:-22.671258, Accept rate:0.746414
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 60001 - 70000 to the text file chain.dat
# 80 % completed; Chain step 80000
# ================= Current logpost:-24.257151, Max logpost:-22.671258, Accept rate:0.743700
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 70001 - 80000 to the text file chain.dat
# 90 % completed; Chain step 90000
# ================= Current logpost:-24.131100, Max logpost:-22.671258, Accept rate:0.741678
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 80001 - 90000 to the text file chain.dat
# 100 % completed; Chain step 100000
# ================= Current logpost:-23.632256, Max logpost:-22.671258, Accept rate:0.739490
# ================= Current MAP params: par(0)=-1.840570 par(1)=-0.009908 par(2)=1.991557
# Written the states 90001 - 100000 to the text file chain.dat
# Status of chain after running AMCMC:
#   => p1   : -1.84057
#   => p2   : -0.00990802
#   => p3   : 1.99156
#   => Data set 1/2:
#        -> x1   : measurement = 2         , prediction = 1.99228
#        -> x2   : measurement = 1.75      , prediction = 1.5139
#        -> x3   : measurement = 1         , prediction = 0.115237
#        -> x4   : measurement = -0.25     , prediction = -2.20371
#        -> x5   : measurement = -2        , prediction = -5.44295
#   => Data set 2/2:
#        -> x1   : measurement = 1.8125    , prediction = 1.86739
#        -> x2   : measurement = 0.3125    , prediction = 0.928864
#        -> x3   : measurement = -2.6875   , prediction = -0.929943
#        -> x4   : measurement = -7.1875   , prediction = -3.70903
# Computing pushforward posteriors:
#   => Computing pushforward posteriors for data set 1/1...
#      => Measurement station 1/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.1.dat
#      => Measurement station 2/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.2.dat
#      => Measurement station 3/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.3.dat
#      => Measurement station 4/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.4.dat
#      => Measurement station 5/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.5.dat
#      => Measurement station 6/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.6.dat
#      => Measurement station 7/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.7.dat
#      => Measurement station 8/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.8.dat
#      => Measurement station 9/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.9.dat
# ╭────────────────────────────────────────────────────╮
# │                       success!                     │
# ╰────────────────────────────────────────────────────╯

# %%
# plot MCMC chains
_, ax = plt.subplots(figsize=(8, 5))
for j, label in enumerate(["a", "b", "c"]):
    ax.plot(chain[:, j + 1], label=label)
ax.legend(loc="upper left", bbox_to_anchor=(1, 1), frameon=False)
ax.set_xlabel("MCMC iterations")
ax.set_ylabel("parameter values")
ax.set_title("MCMC chains")
ax.set_xlim(0, chain.shape[0])
if save:    
    plt.savefig(os.path.join(save_location, "example_3_mcmc_chains.png"))
plt.show()

# %%
# get the MAP prediction
stacked_pushforward = np.vstack(pushforward).T
map_idx = np.argmax(chain[:, -1])
map_prediction = stacked_pushforward[map_idx, :]

# %%
# plot MAP prediction
_, ax = plt.subplots(figsize=(8, 5))
xdata_ = np.zeros(sum([len(x) for x in xdata]))
for j, x in enumerate(xdata):
    xdata_[j::ndata] = x
max_idx = np.argmax(chain[:, -1])
ax.plot(xdata_, map_prediction, color="black")
for j, color in enumerate(["blue", "red"]):
    ax.errorbar(xdata[j], ydata[j], yerr=sdata[j], color=color, linewidth=0, elinewidth=2, capsize=6, marker="o", capthick=2, zorder=100, label=f"data {j + 1}")
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
ax.set_title("MAP prediction")
if save:
    plt.savefig(os.path.join(save_location, "example_3_map_prediction.png"))
plt.show()

# %%
# plot sythetic data sets
for d in range(ndata):
    _, ax = plt.subplots(figsize=(8, 5))
    for i in range(synthetic_data[d].shape[1]):
        ax.scatter(xdata[d], synthetic_data[d][:, i])
    ax.set_xlabel("x")
    ax.set_ylabel("f(x)")
    ax.set_title(f"synthetic data sets (experimental data set {d + 1})")
    if save:
        plt.savefig(os.path.join(save_location, f"example_3_synthetic_data_{d + 1}.png"))
    plt.show()

# %% [markdown]
# ## 4. Weighted calibration

# %%
# perform calibration
with tempfile.TemporaryDirectory() as tmp:

    # save data mean and error bars
    for d in range(ndata):
        np.savetxt(os.path.join(tmp, f"data.{d + 1}.dat"), np.vstack([ydata[d], sdata[d]]).T)

    # save PCE coefficients and multi-indices
    for d in range(ndata):
        for n in range(len(results[d]["pcmi"][0])):
            np.savetxt(os.path.join(tmp, f"pccf.{d + 1}.{n + 1}.dat"), results[d]["pcmi"][0][n])
            np.savetxt(os.path.join(tmp, f"mindex.{d + 1}.{n + 1}.dat"), results[d]["pcmi"][1][n], fmt="%d")
            np.savetxt(os.path.join(tmp, f"pushforward.pccf.{2*n + d + 1}.dat"), results[d]["pcmi"][0][n])
            np.savetxt(os.path.join(tmp, f"pushforward.mindex.{2*n + d + 1}.dat"), results[d]["pcmi"][1][n], fmt="%d")

    # save prior
    with open(os.path.join(tmp, "prior.dat"), "w") as file:
        file.write(f"gaussian {(a_low + a_upp)/2} {(a_upp - a_low)/2}\n")
        file.write(f"gaussian {(b_low + b_upp)/2} {(b_upp - b_low)/2}\n")
        file.write(f"gaussian {(c_low + c_upp)/2} {(c_upp - c_low)/2}\n")

    # run calibration
    subprocess.run(shlex.split(path_to_dfi + " -v pushforward.pccf.{n}.dat -w pushforward.mindex.{n}.dat -g 0.1 -k 100 -m 0 -j 1.99,0.01"), cwd=tmp)

    # load output files
    chain = np.loadtxt(os.path.join(tmp, "chain.dat"))
    pushforward = []
    n = 1
    pushforward_file = os.path.join(tmp, f"pushforward.1.{n}.dat")
    while os.path.isfile(pushforward_file):
        pushforward.append(np.loadtxt(pushforward_file))
        n += 1
        pushforward_file = os.path.join(tmp, f"pushforward.1.{n}.dat")
    synthetic_data = []
    for d in range(ndata):
        synthetic_data.append(np.loadtxt(os.path.join(tmp, f"synthetic.data.{d + 1}.dat")))
# Out:
# ╭────────────────────────────────────────────────────╮
# │                       dfi.x                        │
# ╰────────────────────────────────────────────────────╯
# Found prior:
#   => p1   : mu = -2        , sigma = 1
#   => p2   : mu = 0         , sigma = 0.1
#   => p3   : mu = 2         , sigma = 1
# Found 2 data sets:
#   => Data set number 1/2:
#        -> y1   = 2         s1   = 0.166667
#        -> y2   = 1.75      s2   = 0.25
#        -> y3   = 1         s3   = 0.5
#        -> y4   = -0.25     s4   = 0.916667
#        -> y5   = -2        s5   = 1.5
#   => Data set number 2/2:
#        -> y1   = 1.8125    s1   = 0.1875
#        -> y2   = 0.3125    s2   = 0.354167
#        -> y3   = -2.6875   s3   = 0.6875
#        -> y4   = -7.1875   s4   = 1.1875
# Reading 5 PCE models for data set number 1/2...
#   => PCE number 1:
#        -> PCE coefficients read from file pccf.1.1.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.1.dat (10 x 3)
#   => PCE number 2:
#        -> PCE coefficients read from file pccf.1.2.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.2.dat (10 x 3)
#   => PCE number 3:
#        -> PCE coefficients read from file pccf.1.3.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.3.dat (10 x 3)
#   => PCE number 4:
#        -> PCE coefficients read from file pccf.1.4.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.4.dat (10 x 3)
#   => PCE number 5:
#        -> PCE coefficients read from file pccf.1.5.dat (10 coefficients)
#        -> Multi-indices read from file mindex.1.5.dat (10 x 3)
# Reading 4 PCE models for data set number 2/2...
#   => PCE number 1:
#        -> PCE coefficients read from file pccf.2.1.dat (10 coefficients)
#        -> Multi-indices read from file mindex.2.1.dat (10 x 3)
#   => PCE number 2:
#        -> PCE coefficients read from file pccf.2.2.dat (10 coefficients)
#        -> Multi-indices read from file mindex.2.2.dat (10 x 3)
#   => PCE number 3:
#        -> PCE coefficients read from file pccf.2.3.dat (10 coefficients)
#        -> Multi-indices read from file mindex.2.3.dat (10 x 3)
#   => PCE number 4:
#        -> PCE coefficients read from file pccf.2.4.dat (10 coefficients)
#        -> Multi-indices read from file mindex.2.4.dat (10 x 3)
# Checking consistency of PCE models and data set 1/2...
#   => PCE number 1    : first PCE coefficient = -0.669913 ; measurement mean = 2
#   => PCE number 2    : first PCE coefficient = -0.669913 ; measurement mean = 1.75
#   => PCE number 3    : first PCE coefficient = -0.669913 ; measurement mean = 1
#   => PCE number 4    : first PCE coefficient = -0.669913 ; measurement mean = -0.25
#   => PCE number 5    : first PCE coefficient = -0.669913 ; measurement mean = -2
# Checking consistency of PCE models and data set 2/2...
#   => PCE number 1    : first PCE coefficient = -0.645174 ; measurement mean = 1.8125
#   => PCE number 2    : first PCE coefficient = -0.645174 ; measurement mean = 0.3125
#   => PCE number 3    : first PCE coefficient = -0.645174 ; measurement mean = -2.6875
#   => PCE number 4    : first PCE coefficient = -0.645174 ; measurement mean = -7.1875
# Constructing PCE surrogate models...
#   => 5 PCE surrogate models created for data set 1/2
#   => 4 PCE surrogate models created for data set 2/2
# Found 2 variance scaling factors:
#   => Data set 1    : variance scaling factor = 1
#   => Data set 2    : variance scaling factor = 1
# Generating synthetic data set for data set number 1/2...
#   => Generated synthetic data set of size 5 x 100
#   => Written synthetic data set to file synthetic.data.1.dat
# Generating synthetic data set for data set number 2/2...
#   => Generated synthetic data set of size 4 x 100
#   => Written synthetic data set to file synthetic.data.2.dat
# Using weighted likelihood with weights:
#   => Data set number 1:1.99
#   => Data set number 2:0.01
# Reading pushforward PCE models for data set number 1/2...
#   => PCE number 1:
#        -> PCE coefficients read from file pushforward.pccf.1.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.1.dat (10 x 3)
#   => PCE number 2:
#        -> PCE coefficients read from file pushforward.pccf.2.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.2.dat (10 x 3)
#   => PCE number 3:
#        -> PCE coefficients read from file pushforward.pccf.3.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.3.dat (10 x 3)
#   => PCE number 4:
#        -> PCE coefficients read from file pushforward.pccf.4.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.4.dat (10 x 3)
#   => PCE number 5:
#        -> PCE coefficients read from file pushforward.pccf.5.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.5.dat (10 x 3)
#   => PCE number 6:
#        -> PCE coefficients read from file pushforward.pccf.6.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.6.dat (10 x 3)
#   => PCE number 7:
#        -> PCE coefficients read from file pushforward.pccf.7.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.7.dat (10 x 3)
#   => PCE number 8:
#        -> PCE coefficients read from file pushforward.pccf.8.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.8.dat (10 x 3)
#   => PCE number 9:
#        -> PCE coefficients read from file pushforward.pccf.9.dat (10 coefficients)
#        -> Multi-indices read from file pushforward.mindex.9.dat (10 x 3)
# Setting up MCMC chain of length 100000...
#   => Set random seed of the chain to 1657402178
#   => Set chain covariance to 0.01
#   => Set proposal jump size to 0.1
#   => Set adaptivity parameters to:
#        -> Adapt start = 10000
#        -> Adapt step = 10
#        -> Adapt end = 100000
#        -> Eps cov = 1e-08
#   => Set chain print frequency to 10000
#   => Set burnin to 0
#   => Set subsampling rate to 1
#   => Intialized chain to
#        -> p1   : -2
#        -> p2   : 0
#        -> p3   : 2
# Status of chain before running AMCMC:
#   => p1   : -2
#   => p2   : 0
#   => p3   : 2
#   => Data set 1/2:
#        -> x1   : measurement = 2         , prediction = 2.00049
#        -> x2   : measurement = 1.75      , prediction = 1.50049
#        -> x3   : measurement = 1         , prediction = 0.000485449
#        -> x4   : measurement = -0.25     , prediction = -2.49951
#        -> x5   : measurement = -2        , prediction = -5.99951
#   => Data set 2/2:
#        -> x1   : measurement = 1.8125    , prediction = 1.87462
#        -> x2   : measurement = 0.3125    , prediction = 0.874618
#        -> x3   : measurement = -2.6875   , prediction = -1.12538
#        -> x4   : measurement = -7.1875   , prediction = -4.12538
# Starting AMCMC...
# 10 % completed; Chain step 10000
# ================= Current logpost:-9.432583, Max logpost:-8.730313, Accept rate:0.926500
# ================= Current MAP params: par(0)=-1.056749 par(1)=0.017412 par(2)=2.008963
# Written the states 0 - 10000 to the text file chain.dat
# 20 % completed; Chain step 20000
# ================= Current logpost:-12.455628, Max logpost:-8.729259, Accept rate:0.800050
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 10001 - 20000 to the text file chain.dat
# 30 % completed; Chain step 30000
# ================= Current logpost:-9.411597, Max logpost:-8.729259, Accept rate:0.764633
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 20001 - 30000 to the text file chain.dat
# 40 % completed; Chain step 40000
# ================= Current logpost:-9.886566, Max logpost:-8.729259, Accept rate:0.750225
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 30001 - 40000 to the text file chain.dat
# 50 % completed; Chain step 50000
# ================= Current logpost:-10.133198, Max logpost:-8.729259, Accept rate:0.740540
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 40001 - 50000 to the text file chain.dat
# 60 % completed; Chain step 60000
# ================= Current logpost:-10.815401, Max logpost:-8.729259, Accept rate:0.735283
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 50001 - 60000 to the text file chain.dat
# 70 % completed; Chain step 70000
# ================= Current logpost:-10.921106, Max logpost:-8.729259, Accept rate:0.729729
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 60001 - 70000 to the text file chain.dat
# 80 % completed; Chain step 80000
# ================= Current logpost:-9.711788, Max logpost:-8.729259, Accept rate:0.726025
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 70001 - 80000 to the text file chain.dat
# 90 % completed; Chain step 90000
# ================= Current logpost:-9.867973, Max logpost:-8.729259, Accept rate:0.723289
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 80001 - 90000 to the text file chain.dat
# 100 % completed; Chain step 100000
# ================= Current logpost:-10.906462, Max logpost:-8.729259, Accept rate:0.722290
# ================= Current MAP params: par(0)=-1.066763 par(1)=0.014757 par(2)=2.008961
# Written the states 90001 - 100000 to the text file chain.dat
# Status of chain after running AMCMC:
#   => p1   : -1.06676
#   => p2   : 0.0147566
#   => p3   : 2.00896
#   => Data set 1/2:
#        -> x1   : measurement = 2         , prediction = 2.01032
#        -> x2   : measurement = 1.75      , prediction = 1.75937
#        -> x3   : measurement = 1         , prediction = 0.97504
#        -> x4   : measurement = -0.25     , prediction = -0.342672
#        -> x5   : measurement = -2        , prediction = -2.19376
#   => Data set 2/2:
#        -> x1   : measurement = 1.8125    , prediction = 1.95345
#        -> x2   : measurement = 0.3125    , prediction = 1.43581
#        -> x3   : measurement = -2.6875   , prediction = 0.384785
#        -> x4   : measurement = -7.1875   , prediction = -1.19962
# Computing pushforward posteriors:
#   => Computing pushforward posteriors for data set 1/1...
#      => Measurement station 1/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.1.dat
#      => Measurement station 2/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.2.dat
#      => Measurement station 3/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.3.dat
#      => Measurement station 4/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.4.dat
#      => Measurement station 5/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.5.dat
#      => Measurement station 6/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.6.dat
#      => Measurement station 7/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.7.dat
#      => Measurement station 8/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.8.dat
#      => Measurement station 9/9...
#         --> Batching samples 1 to 100000...
#         --> Batching samples 100001 to 100001...
#        -> Pushforward written to file pushforward.1.9.dat
# ╭────────────────────────────────────────────────────╮
# │                       success!                     │
# ╰────────────────────────────────────────────────────╯

# %%
# plot MCMC chains
_, ax = plt.subplots(figsize=(8, 5))
for j, label in enumerate(["a", "b", "c"]):
    ax.plot(chain[:, j + 1], label=label)
ax.legend(loc="upper left", bbox_to_anchor=(1, 1), frameon=False)
ax.set_xlabel("MCMC iterations")
ax.set_ylabel("parameter values")
ax.set_title("MCMC chains")
ax.set_xlim(0, chain.shape[0])
if save:    
    plt.savefig(os.path.join(save_location, "example_3_mcmc_chains_weighted.png"))
plt.show()

# %%
# get the MAP prediction
stacked_pushforward = np.vstack(pushforward).T
map_idx = np.argmax(chain[:, -1])
map_prediction = stacked_pushforward[map_idx, :]

# %%
# plot MAP prediction
_, ax = plt.subplots(figsize=(8, 5))
xdata_ = np.zeros(sum([len(x) for x in xdata]))
for j, x in enumerate(xdata):
    xdata_[j::ndata] = x
max_idx = np.argmax(chain[:, -1])
ax.plot(xdata_, map_prediction, color="black")
for j, color in enumerate(["blue", "red"]):
    ax.errorbar(xdata[j], ydata[j], yerr=sdata[j], color=color, linewidth=0, elinewidth=2, capsize=6, marker="o", capthick=2, zorder=100, label=f"data {j + 1}")
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
ax.set_title("MAP prediction")
if save:
    plt.savefig(os.path.join(save_location, "example_3_map_prediction_weighted.png"))
plt.show()
